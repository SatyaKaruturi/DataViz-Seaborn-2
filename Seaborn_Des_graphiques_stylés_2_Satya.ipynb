# %% [markdown]
# # Mission 1
#
# Reproduit le visuel ci-dessous avec Seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt


rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,cmap='viridis')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame()
rng = np.random.RandomState(0)
df['x'] = rng.randn(100)
df['y'] = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

sns.scatterplot('x', 'y', data=df,palette='viridis', hue=sizes, s=sizes, alpha=0.3)

# %% [markdown]
# # Mission 2
#
# Reproduit le visuel ci-dessous avec Seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(19680801)

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots()
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set(xlabel='entry a', ylabel='entry b')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(19680801)

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots()
sns.scatterplot(x= 'a', y= 'b',hue='d',size='d',palette='viridis', data=data)
ax.set(xlabel='entry a', ylabel='entry b')
plt.show()

# %% [markdown]
# # Mission 3
#
# ![box plot](http://www.datasciencemadesimple.com/wp-content/uploads/2017/08/Box-plot-in-python-4.png)
#
# Reproduit le visuel ci-dessus avec Seaborn

# %%
import matplotlib.pyplot as plt

box_plot_data = pd.DataFrame()
box_plot_data['course1'] = [82,76,24,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]
box_plot_data['course2'] = [62,5,91,25,36,32,96,95,3,90,95,32,27,55,100,15,71,11,37,21]
box_plot_data['course3'] = [23,89,12,78,72,89,25,69,68,86,19,49,15,16,16,75,65,31,25,52]
box_plot_data['course4'] = [59,73,70,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]

colors = ['tan', 'lightgreen', 'lightblue', 'cyan']


box=sns.boxplot(data=box_plot_data, orient="h", palette=colors, order=['course4', 'course3', 'course2','course1'])

 
plt.show()

# %% [markdown]
# # Mission 4
#
# Reproduit le visuel ci-dessous avec Seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

np.random.seed(19680801)


all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]

axes[0].violinplot(all_data,
                   showmeans=False,
                   showmedians=True)
axes[0].set_title('Violin plot')

axes[1].boxplot(all_data)
axes[1].set_title('Box plot')

for ax in axes:
    ax.yaxis.grid(True)
    ax.set_xticks([y + 1 for y in range(len(all_data))])
    ax.set_xlabel('Four separate samples')
    ax.set_ylabel('Observed values')

plt.setp(axes, xticks=[y + 1 for y in range(len(all_data))],
         xticklabels=['x1', 'x2', 'x3', 'x4'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

np.random.seed(19680801)


all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]

sns.violinplot(data = all_data,
                   showmeans=False,
                   showmedians=True, ax=axes[0])
axes[0].set_title('Violin plot')

sns.boxplot(data=all_data, ax=axes[1])
axes[1].set_title('Box plot')

for ax in axes:
    ax.yaxis.grid(True)
    ax.set_xticks([y + 0 for y in range(len(all_data))])
    ax.set_xlabel('Four separate samples')
    ax.set_ylabel('Observed values')

plt.setp(axes, xticks=[y + 0 for y in range(len(all_data))],
         xticklabels=['x1', 'x2', 'x3', 'x4'])
plt.show()

# %% [markdown]
# # Mission 5
#
# Applique le heatmat ci-dessous sur des colonnes de ton choix du dataset Pokemon ci-après : https://www.kaggle.com/abcsds/pokemon

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)

# %% [markdown]
# # Mission 6
#
# Que fait la méthode sns.pairplot() ?

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cac16c25-5df7-43c6-948d-ada3bc7b5c97" name="files[]" multiple disabled />
#      <output id="result-cac16c25-5df7-43c6-948d-ada3bc7b5c97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pokemon.csv to pokemon.csv

# %%
import io
import pandas as pd
pokemon_d1 = pd.read_csv(io.BytesIO(uploaded['pokemon.csv']))

# %%
hetamap_data = pokemon_d1[['Type 1','Generation', 'Speed']]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

hetamap1_data = pd.pivot_table(hetamap_data, values = 'Speed', index=['Type 1'], columns='Generation') 

f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(hetamap1_data, annot=True,linewidths=.5, ax=ax)
